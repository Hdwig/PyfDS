# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")

# %%
ds_file = r"D:\Users\G_Gerasimov\Desktop\GBU\PDinDS\PyfDS\for_homework\Lesson_4\creditcard.csv"
ds = pd.read_csv(ds_file)
f = ds["Class"].value_counts()
f
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
f.plot(kind="bar")
plt.show()

# %%
f.plot(kind="bar", logy=True)
plt.show()

# %%
uam = ds.set_index("Class")["V1"]
# uam.plot.density()
# plt.show()
wn = uam.loc[0]
wf = uam.loc[1]
wf
# Out:
# Class
# 1   -2.312227
# 1   -3.043541
# 1   -2.303350
# 1   -4.397974
# 1    1.234235
#        ...
# 1   -1.927883
# 1    1.378559
# 1   -0.676143
# 1   -3.113832
# 1    1.991976
# Name: V1, Length: 492, dtype: float64

# %%
wn.hist(bins = 20, density = True, alpha = .5, label = "Class 0", color="grey")
wf.hist(bins = 20, density = True, alpha = .5, label = "Class 1", color="red")
plt.legend()
plt.ylabel("V1")
plt.show()
